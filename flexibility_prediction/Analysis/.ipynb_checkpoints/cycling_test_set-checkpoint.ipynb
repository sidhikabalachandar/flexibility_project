# %%
# %load_ext autoreload
# %autoreload 1
# %aimport prediction

# %%
(data, prots) = prediction.load_data()
data.columns
# Out:
# Index(['protein', 'start ligand', 'target ligand', 'name', 'num', 'bfactor',
#        'normalized bfactor', 'prev prev bfactor', 'prev bfactor',
#        'next bfactor', 'next next bfactor', 'mol weight',
#        'general number of rotamers', 'general avg rmsd of rotamers',
#        'specific number of rotamers', 'specific avg rmsd of rotamers',
#        'solvent accessibility', 'secondary structure', 'ligand similarity',
#        'ligand similarity ratio', 'ligand size difference',
#        'ligand size ratio', 'complete rmsd', 'backbone rmsd',
#        'sidechain rmsd'],
#       dtype='object')

# %%
# %reload_ext autoreload
print("With Rotamer Info:")

(data, prots) = prediction.load_data()
test_scores = []
lin_reg = []
dec_tree = []
for test_prot in prots:
    train_data = data[data['protein'] != test_prot]
    test_data = data[data['protein'] == test_prot]
    ignore_cols = ['protein', 'start ligand', 'target ligand', 'name', 'num', 'complete rmsd', 'backbone rmsd', 'sidechain rmsd']
    (dict_models, scores) = prediction.run_pred(train_data, test_data, ignore_cols, lin_reg, dec_tree)
    test_scores.append(scores)
prediction.results(test_scores, prots)
# print(lin_reg)
# print(dec_tree)
# Out:
# With Rotamer Info:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-0dd274801430> in <module>
#      10     test_data = data[data['protein'] == test_prot]
#      11     ignore_cols = ['protein', 'start ligand', 'target ligand', 'name', 'num', 'complete rmsd', 'backbone rmsd', 'sidechain rmsd']
# ---> 12     (dict_models, scores) = prediction.run_pred(train_data, test_data, ignore_cols, lin_reg, dec_tree)
#      13     test_scores.append(scores)
#      14 prediction.results(test_scores, prots)
#
# ~/Documents/Sidhika/2019/Dror Lab/flexibility_project/flexibility_prediction/Analysis/prediction.py in run_pred(train_data, test_data, ignore_cols, lin_reg, dec_tree)
#     127
#     128 def run_pred(train_data, test_data, ignore_cols, lin_reg, dec_tree):
# --> 129     X_train = train_data.drop(ignore_cols, axis=1).values
# ...

# %%
import pandas as pd
import statistics
import numpy as np
avg_lin_reg = []
avg_lin_reg.append(data.columns[5:22])
avg_lin_reg.append([abs(statistics.mean([lin_reg[x][y] for x in range(len(lin_reg))])) for y in range(len(lin_reg[0]))])
df = pd.DataFrame(avg_lin_reg)
print('Linear Regression:')
print(df.iloc[:, np.argsort(df.iloc[1])])

avg_dec_tree = []
avg_dec_tree.append(data.columns[5:22])
avg_dec_tree.append([abs(statistics.mean([dec_tree[x][y] for x in range(len(dec_tree))])) for y in range(len(dec_tree[0]))])
df = pd.DataFrame(avg_dec_tree)
print('Decision Tree:')
print(df.iloc[:, np.argsort(df.iloc[1])])
# Out:
# Linear Regression:
#                   13                      15                     11  \
# 0  ligand similarity  ligand size difference  solvent accessibility
# 1        0.000645536              0.00619116             0.00824216
#
#            6                            9                           7   \
# 0  mol weight  specific number of rotamers  general number of rotamers
# 1  0.00880748                    0.0147691                   0.0151399
#
#                              8          0             3                  2   \
# 0  general avg rmsd of rotamers    bfactor  prev bfactor  prev prev bfactor
# 1                     0.0156495  0.0175722     0.0275912          0.0565553
#
#                   16                 5                              10  \
# 0  ligand size ratio  next next bfactor  specific avg rmsd of rotamers
# 1          0.0989383           0.208302                        0.22974
#
#              4                    12                  1   \
# ...

# %%
# %reload_ext autoreload
print("Without Rotamer Info:")

(data, prots) = prediction.load_data()
test_scores = []
for test_prot in prots:
    train_data = data[data['protein'] != test_prot]
    test_data = data[data['protein'] == test_prot]
    ignore_cols = ['protein', 'start ligand', 'target ligand', 'name', 'num', 'complete rmsd', 
                   'general number of rotamers', 'general avg rmsd of rotamers', 'specific number of rotamers', 
                   'specific avg rmsd of rotamers', 'backbone rmsd', 'sidechain rmsd']
    (dict_models, scores) = prediction.run_pred(train_data, test_data, ignore_cols)
    test_scores.append(scores)
prediction.results(test_scores, prots)
# Out:
# Without Rotamer Info:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-1858e26f8904> in <module>
#      10                    'general number of rotamers', 'general avg rmsd of rotamers', 'specific number of rotamers',
#      11                    'specific avg rmsd of rotamers', 'backbone rmsd', 'sidechain rmsd']
# ---> 12     (dict_models, scores) = prediction.run_pred(train_data, test_data, ignore_cols)
#      13     test_scores.append(scores)
#      14 prediction.results(test_scores, prots)
#
# TypeError: run_pred() missing 2 required positional arguments: 'lin_reg' and 'dec_tree'

# %%
data[(data['protein'] == 'MAPK14') & (data['start ligand'] == '1KV1') & (data['target ligand'] == '1YQJ')].drop(['secondary structure', 'ligand similarity', 'ligand similarity ratio', 'ligand size difference', 'ligand size ratio', 'prev prev bfactor', 'prev bfactor', 'next bfactor', 'next next bfactor', 'mol weight'], axis=1)
# Out:
#    protein start ligand target ligand  name  num    bfactor  \
# 0   MAPK14         1KV1          1YQJ  ALA    34  58.630000
# 1   MAPK14         1KV1          1YQJ  TYR    35  57.938333
# 2   MAPK14         1KV1          1YQJ  VAL    38  38.252857
# 3   MAPK14         1KV1          1YQJ  ALA    51  29.968000
# 4   MAPK14         1KV1          1YQJ  VAL    52  28.888571
# 5   MAPK14         1KV1          1YQJ  LYS    53  33.725556
# 6   MAPK14         1KV1          1YQJ  GLU    71  26.585556
# 7   MAPK14         1KV1          1YQJ  LEU    74  22.332500
# 8   MAPK14         1KV1          1YQJ  LEU    75  23.462500
# 9   MAPK14         1KV1          1YQJ  MET    78  22.463750
# 10  MAPK14         1KV1          1YQJ  VAL    83  19.841429
# 11  MAPK14         1KV1          1YQJ  ILE    84  20.330000
# 12  MAPK14         1KV1          1YQJ  LEU    86  26.912500
# 13  MAPK14         1KV1          1YQJ  LEU   104  22.052500
# 14  MAPK14         1KV1          1YQJ  VAL   105  23.282857
# ...

# %%
# %reload_ext autoreload
(data, prots) = prediction.load_data()
test_prot = 'F10'
start = '2J94'
target = '1Z6E'
test_data = data[(data['protein'] == test_prot) & (data['start ligand'] == start) & (data['target ligand'] == target)]
ignore_cols = ['protein', 'start ligand', 'target ligand', 'name', 'num', 'complete rmsd', 'backbone rmsd', 'sidechain rmsd']
(dict_models, scores) = prediction.run_pred(train_data, test_data, ignore_cols)
print(pd.DataFrame.from_dict(scores, orient='index'))
prediction.actual_rmsd_grapher(data, test_prot, start, target)
models = ['Linear Regression', 'Polynomial Regression', 'Decision Tree with Max Depth = 03', 'Decision Tree with Max Depth = 05']
for model in models:
    prediction.pred_rmsd_grapher(dict_models, model, data, test_prot, start, target)
# Out:
#                                    Accuracy    Recall  Precision
# Decision Tree                      0.956522  1.000000   0.750000
# Decision Tree with Max Depth = 03  0.608696  1.000000   0.250000
# Decision Tree with Max Depth = 05  0.652174  1.000000   0.272727
# Decision Tree with Max Depth = 10  0.826087  0.666667   0.400000
# Decision Tree with Max Depth = 15  0.956522  1.000000   0.750000
# Linear Regression                  0.521739  1.000000   0.214286
# Polynomial Regression              0.695652  1.000000   0.300000

# %%
import pandas as pd
# %reload_ext autoreload
(data, prots) = prediction.load_data()
test_prot = 'NR3C2'
train_data = data[data['protein'] != test_prot]
start = '2A3I'
target = '5MWP'
test_data = data[(data['protein'] == test_prot) & (data['start ligand'] == start) & (data['target ligand'] == target)]
ignore_cols = ['protein', 'start ligand', 'target ligand', 'name', 'num', 'complete rmsd', 'backbone rmsd', 'sidechain rmsd']
(dict_models, scores) = prediction.run_pred(train_data, test_data, ignore_cols)
print(pd.DataFrame.from_dict(scores, orient='index'))
prediction.actual_rmsd_grapher(data, test_prot, start, target)
models = ['Linear Regression', 'Polynomial Regression', 'Decision Tree with Max Depth = 03', 'Decision Tree with Max Depth = 05']
for model in models:
    prediction.pred_rmsd_grapher(dict_models, model, data, test_prot, start, target)
# Out:
#                                    Accuracy  Recall  Precision
# Decision Tree                          0.76     0.2   0.333333
# Decision Tree with Max Depth = 03      0.72     0.2   0.250000
# Decision Tree with Max Depth = 05      0.76     0.4   0.400000
# Decision Tree with Max Depth = 10      0.76     0.4   0.400000
# Decision Tree with Max Depth = 15      0.68     0.2   0.200000
# Linear Regression                      0.76     0.6   0.428571
# Polynomial Regression                  0.76     0.2   0.333333

# %%
# %reload_ext autoreload
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
(data, prots) = prediction.load_data()
test_prot = 'MAPK14'
train_data = data[data['protein'] != test_prot]
start = '2YIX'
target = '3D83'
test_data = data[(data['protein'] == test_prot) & (data['start ligand'] == start) & (data['target ligand'] == target)]
ignore_cols = ['protein', 'start ligand', 'target ligand', 'name', 'num', 'complete rmsd', 'backbone rmsd', 'sidechain rmsd']
(dict_models, scores) = prediction.run_pred(train_data, test_data, ignore_cols)
print(pd.DataFrame.from_dict(scores, orient='index'))
# prediction.actual_rmsd_grapher(data, test_prot, start, target)
plt.subplot(411)
selected = data[(data['protein'] == test_prot) & (data['start ligand'] == start) & (data['target ligand'] == target)]
rmsd = np.array(selected['complete rmsd'])
rmsd[rmsd > 8] = 8
rmsd_formatted = np.expand_dims(rmsd, axis=0)
sns.set_context("talk", font_scale=1.0)

plt.imshow(rmsd_formatted, cmap="plasma", interpolation='none')

fig = plt.gcf()
fig.set_size_inches(10, 3)

ax = plt.gca()
labels = [r + '\n' + str(i) for r, i in zip(selected['name'], selected['num'])]
plt.xticks(np.arange(0, len(selected)), labels)
plt.yticks([], [])
ax.tick_params(axis=u'both', which=u'both', length=0)
ax.tick_params(axis='both', labelsize=5.5)
plt.title(test_prot + ', start ligand =' + start + ', target ligand =' + target)
models = ['Linear Regression', 'Polynomial Regression', 'Decision Tree with Max Depth = 03']
for i, model in enumerate(models):
    plt.subplot(410 + i + 2)
    selected = data[(data['protein'] == test_prot) & (data['start ligand'] == start) & (data['target ligand'] == target)]
    bin_pred_rmsd_formatted = np.expand_dims(dict_models[model]['y_pred'], axis=0)
    sns.set_context("talk", font_scale=1.0)
    plt.imshow(bin_pred_rmsd_formatted, cmap="plasma", interpolation='none')
    fig = plt.gcf()
    fig.set_size_inches(10, 3)

    ax = plt.gca()
    labels = [r + '\n' + str(i) for r, i in zip(selected['name'], selected['num'])]
    plt.xticks(np.arange(0, len(selected)), labels)
    plt.yticks([], [])
    ax.tick_params(axis=u'both', which=u'both', length=0)
    ax.tick_params(axis='both', labelsize=5.5)
    plt.title(model)
    
plt.subplots_adjust(bottom=0.8, left=0, top=2.4, right=0.8)
cax = plt.axes([0.9, 0.1, 0.02, 0.8])
plt.colorbar(cax=cax)
plt.show()
# Out:
#                                    Accuracy  Recall  Precision
# Decision Tree                      0.696970     0.4   0.500000
# Decision Tree with Max Depth = 03  0.666667     0.4   0.444444
# Decision Tree with Max Depth = 05  0.757576     0.3   0.750000
# Decision Tree with Max Depth = 10  0.727273     0.3   0.600000
# Decision Tree with Max Depth = 15  0.666667     0.5   0.454545
# Linear Regression                  0.727273     0.2   0.666667
# Polynomial Regression              0.606061     0.5   0.384615

# %%
# %reload_ext autoreload
dot_data = tree.export_graphviz(dict_classifiers['Decision Tree with Max Depth = 03'], out_file=None, feature_names=data.columns[5:22], filled=True, rounded=True, special_characters=True)  
graph = graphviz.Source(dot_data)
graph
