# %%
import prediction
import importlib

# %%
importlib.reload(prediction)
X_train_expanded_50 = np.append(X_train, X_true, axis=0)
Y_train_expanded_50 = np.append(Y_train, Y_true, axis=0)

for i in range(4):
    X_train_expanded_50 = np.append(X_train_expanded_50, X_true, axis=0)
    Y_train_expanded_50 = np.append(Y_train_expanded_50, Y_true, axis=0)
    
print('Ratio of positive examples (50)', np.sum(Y_train_expanded)/len(Y_train_expanded))

X_train_expanded_25 = np.append(X_train, X_true, axis=0)
Y_train_expanded_25 = np.append(Y_train, Y_true, axis=0)
    
print('Ratio of positive examples (25)', np.sum(Y_train_expanded_25)/len(Y_train_expanded_25))

X_train_expanded_75 = np.append(X_train, X_true, axis=0)
Y_train_expanded_75 = np.append(Y_train, Y_true, axis=0)

for i in range(17):
    X_train_expanded_75 = np.append(X_train_expanded_75, X_true, axis=0)
    Y_train_expanded_75 = np.append(Y_train_expanded_75, Y_true, axis=0)
    
print('Ratio of positive examples (75)', np.sum(Y_train_expanded_75)/len(Y_train_expanded_75))
# Out:
# Ratio of positive examples (50) 0.4815540403012416
# Ratio of positive examples (25) 0.2364160983287117
# Ratio of positive examples (75) 0.7462785992217899

# %%
importlib.reload(prediction)
dict_models = batch_classify(X_train_expanded_25, Y_train_expanded_25, X_test, Y_test)
print("Not taking res name into account:")
pd.DataFrame.from_dict(dict_models, orient='index')
# Out:
# /Users/sbalachandar/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# trained Logistic Regression in 0.49 s
# trained Decision Tree in 1.95 s
# trained Decision Tree with max depth = 03 in 0.15 s
# trained Decision Tree with max depth = 05 in 0.22 s
# trained Decision Tree with max depth = 10 in 0.33 s
# trained Decision Tree with max depth = 15 in 0.43 s
# trained Random Forest in 22.94 s
# trained Naive Bayes in 0.25 s
# Not taking res name into account:
#                                                                model  \
# Decision Tree                                          Decision Tree
# Decision Tree with max depth = 03  Decision Tree with max depth = 03
# Decision Tree with max depth = 05  Decision Tree with max depth = 05
# Decision Tree with max depth = 10  Decision Tree with max depth = 10
# Decision Tree with max depth = 15  Decision Tree with max depth = 15
# Logistic Regression                              Logistic Regression
# Naive Bayes                                              Naive Bayes
# Random Forest                                          Random Forest
#
#                                    train_score  test_score  recall_score  \
# Decision Tree                         0.906889    0.738946      0.353316
# Decision Tree with max depth = 03     0.780063    0.854102      0.209494
# Decision Tree with max depth = 05     0.785908    0.803519      0.363993
# Decision Tree with max depth = 10     0.819952    0.795045      0.320962
# Decision Tree with max depth = 15     0.867801    0.762627      0.313501
# Logistic Regression                   0.778756    0.835215      0.280762
# Naive Bayes                           0.770830    0.799633      0.381295
# Random Forest                         0.906889    0.792545      0.308162
#
#                                    precision_score  train_time
# Decision Tree                             0.235569    1.950076
# Decision Tree with max depth = 03         0.497404    0.152774
# Decision Tree with max depth = 05         0.337770    0.215034
# Decision Tree with max depth = 10         0.305741    0.332546
# Decision Tree with max depth = 15         0.249297    0.429176
# Logistic Regression                       0.404879    0.487280
# Naive Bayes                               0.334783    0.246710
# Random Forest                             0.295923   22.941426

# %%
importlib.reload(prediction)
dict_models = batch_classify(X_train_expanded_50, Y_train_expanded_50, X_test, Y_test)
print("Not taking res name into account:")
pd.DataFrame.from_dict(dict_models, orient='index')
# Out:
# /Users/sbalachandar/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# trained Logistic Regression in 0.67 s
# trained Decision Tree in 2.83 s
# trained Decision Tree with max depth = 03 in 1.00 s
# trained Decision Tree with max depth = 05 in 1.83 s
# trained Decision Tree with max depth = 10 in 2.37 s
# trained Decision Tree with max depth = 15 in 2.52 s
# trained Random Forest in 209.08 s
# trained Naive Bayes in 0.47 s
# Not taking res name into account:
#                                                                model  \
# Decision Tree                                          Decision Tree
# Decision Tree with max depth = 03  Decision Tree with max depth = 03
# Decision Tree with max depth = 05  Decision Tree with max depth = 05
# Decision Tree with max depth = 10  Decision Tree with max depth = 10
# Decision Tree with max depth = 15  Decision Tree with max depth = 15
# Logistic Regression                              Logistic Regression
# Naive Bayes                                              Naive Bayes
# Random Forest                                          Random Forest
#
#                                    train_score  test_score  recall_score  \
# Decision Tree                         0.900398    0.696650      0.443430
# Decision Tree with max depth = 03     0.662865    0.645991      0.583907
# Decision Tree with max depth = 05     0.673417    0.591157      0.651766
# Decision Tree with max depth = 10     0.734951    0.647134      0.614331
# Decision Tree with max depth = 15     0.820072    0.686724      0.496366
# Logistic Regression                   0.659112    0.637639      0.614781
# Naive Bayes                           0.638030    0.702511      0.534251
# Random Forest                         0.900392    0.753937      0.391908
#
#                                    precision_score  train_time
# Decision Tree                             0.225022    2.833902
# Decision Tree with max depth = 03         0.224620    0.998370
# Decision Tree with max depth = 05         0.209442    1.830270
# Decision Tree with max depth = 10         0.231601    2.367798
# Decision Tree with max depth = 15         0.231443    2.519562
# Logistic Regression                       0.226134    0.666812
# Naive Bayes                               0.252962    0.467930
# Random Forest                             0.265872  209.081108

# %%
importlib.reload(prediction)
dict_models = batch_classify(X_train_expanded_50, Y_train_expanded_50, X_test, Y_test)
print("Not taking res name into account:")
pd.DataFrame.from_dict(dict_models, orient='index')
# Out:
# /Users/sbalachandar/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# trained Logistic Regression in 0.67 s
# trained Decision Tree in 2.84 s
# trained Decision Tree with max depth = 03 in 0.99 s
# trained Decision Tree with max depth = 05 in 1.99 s
# trained Decision Tree with max depth = 10 in 2.37 s
# trained Decision Tree with max depth = 15 in 2.49 s
# trained Random Forest in 206.11 s
# trained Naive Bayes in 0.43 s
# Not taking res name into account:
#                                                                model  \
# Decision Tree                                          Decision Tree
# Decision Tree with max depth = 03  Decision Tree with max depth = 03
# Decision Tree with max depth = 05  Decision Tree with max depth = 05
# Decision Tree with max depth = 10  Decision Tree with max depth = 10
# Decision Tree with max depth = 15  Decision Tree with max depth = 15
# Logistic Regression                              Logistic Regression
# Naive Bayes                                              Naive Bayes
# Random Forest                                          Random Forest
#
#                                    train_score  test_score  recall_score  \
# Decision Tree                         0.900398    0.695929      0.442979
# Decision Tree with max depth = 03     0.662865    0.645991      0.583907
# Decision Tree with max depth = 05     0.673417    0.591157      0.651766
# Decision Tree with max depth = 10     0.734951    0.647349      0.614459
# Decision Tree with max depth = 15     0.820072    0.684879      0.487554
# Logistic Regression                   0.659112    0.637639      0.614781
# Naive Bayes                           0.638030    0.702511      0.534251
# Random Forest                         0.900395    0.751700      0.397247
#
#                                    precision_score  train_time
# Decision Tree                             0.224332    2.843742
# Decision Tree with max depth = 03         0.224620    0.988768
# Decision Tree with max depth = 05         0.209442    1.994422
# Decision Tree with max depth = 10         0.231756    2.366174
# Decision Tree with max depth = 15         0.227860    2.494428
# Logistic Regression                       0.226134    0.674052
# Naive Bayes                               0.252962    0.426060
# Random Forest                             0.264814  206.108090

# %%
importlib.reload(prediction)
dict_models = batch_classify(X_train_expanded_75, Y_train_expanded_75, X_test, Y_test)
print("Not taking res name into account:")
pd.DataFrame.from_dict(dict_models, orient='index')
# Out:
# /Users/sbalachandar/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# trained Logistic Regression in 1.40 s
# trained Decision Tree in 3.80 s
# trained Decision Tree with max depth = 03 in 2.15 s
# trained Decision Tree with max depth = 05 in 2.60 s
# trained Decision Tree with max depth = 10 in 2.86 s
# trained Decision Tree with max depth = 15 in 3.12 s
# trained Random Forest in 304.61 s
# trained Naive Bayes in 0.87 s
# Not taking res name into account:
#                                                                model  \
# Decision Tree                                          Decision Tree
# Decision Tree with max depth = 03  Decision Tree with max depth = 03
# Decision Tree with max depth = 05  Decision Tree with max depth = 05
# Decision Tree with max depth = 10  Decision Tree with max depth = 10
# Decision Tree with max depth = 15  Decision Tree with max depth = 15
# Logistic Regression                              Logistic Regression
# Naive Bayes                                              Naive Bayes
# Random Forest                                          Random Forest
#
#                                    train_score  test_score  recall_score  \
# Decision Tree                         0.933675    0.667556      0.467293
# Decision Tree with max depth = 03     0.754374    0.324831      0.885251
# Decision Tree with max depth = 05     0.764809    0.270053      0.921014
# Decision Tree with max depth = 10     0.807605    0.393103      0.818357
# Decision Tree with max depth = 15     0.872445    0.532567      0.673699
# Logistic Regression                   0.752798    0.172781      0.979867
# Naive Bayes                           0.722677    0.335075      0.898244
# Random Forest                         0.933672    0.712465      0.450248
#
#                                    precision_score  train_time
# Decision Tree                             0.210665    3.798600
# Decision Tree with max depth = 03         0.163684    2.150200
# Decision Tree with max depth = 05         0.157274    2.595948
# Decision Tree with max depth = 10         0.170294    2.855774
# Decision Tree with max depth = 15         0.189335    3.115544
# Logistic Regression                       0.147526    1.402744
# Naive Bayes                               0.167460    0.871018
# Random Forest                             0.240055  304.614856

# %%
importlib.reload(prediction)
print('Train proteins are', train_prots)
print('Test proteins are', test_prots)
print('Test size is', len(test_data) / len(data))
# Out:
# Train proteins are ['5HT2B' 'PLK1' 'SMO' 'NR3C2' 'B2AR' 'CDK2' 'BACE1' 'F2' 'B1AR' 'VDR'
#  'CHRM3' 'PDE10A' 'PLAU' 'BRD4' 'ERA' 'AR' 'HSP90AA1' 'SLC6A4' 'GLUT1'
#  'BRAF' 'JAK2' 'F11' 'DHFR']
# Test proteins are ['MAPK14' 'PYGM' 'NR3C1' 'CHK1' 'MGLUR5' 'DAT' 'SIGMAR1' 'PTPN1' 'F10'
#  'MEK1' 'ELANE' 'P00760']
# Test size is 0.3619571185510056
